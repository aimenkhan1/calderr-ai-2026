# %%
#My First LLM Call
This notebook demonstrates how to make an API call to a Groq-hosted LLM using LangChain.

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
#Step 1: Load API Keys
We use python-dotenv to load our secret keys from the .env file

# %%
load_dotenv()
print("Keys loaded!")
# Out:
# Keys loaded!

# %%
#Step 2: Setup the LLM
We connect to llama-3.3-70b model running on Groq's servers

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7,
    api_key=os.getenv("GROQ_API_KEY")
)
print("LLM ready!")
# Out:
# LLM ready!

# %%
#Step 3: Build Chain and Run
We build a prompt | llm | parser chain and invoke it with our question

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI engineering assistant."),
    ("user", "{question}")
])

chain = prompt | llm | StrOutputParser()

response = chain.invoke({"question": "What is an AI agent?"})
print(response)
# Out:
# An AI agent is a program or system that uses artificial intelligence (AI) and machine learning (ML) to perform tasks autonomously, making decisions and taking actions based on its environment, goals, and constraints. AI agents can be designed to operate in various domains, such as:
#
# 1. **Virtual environments**: Simulated worlds, games, or virtual reality.
# 2. **Physical environments**: Robots, autonomous vehicles, or other physical systems.
# 3. **Cyber environments**: Networks, databases, or other digital systems.
#
# AI agents typically possess the following characteristics:
#
# 1. **Autonomy**: Ability to operate independently, making decisions without human intervention.
# 2. **Reactivity**: Ability to respond to changes in the environment or react to events.
# 3. **Proactivity**: Ability to take initiative and perform actions to achieve goals.
# 4. **Social ability**: Ability to interact with other agents or humans, if necessary.
#
# ...
